# %% [markdown]
# ## Vizualization of car dekho

# %%
## importing required packages

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %%
## importing data

data = pd.read_csv("cleaned_details.csv")

data = data.iloc[:, 1:]

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ignition_type        8369 non-null   int64
#  1   kilometers_driven    8369 non-null   float64
#  2   ownerNo              8369 non-null   int64
#  3   modelYear            8369 non-null   int64
#  4   centralVariantId     8369 non-null   int64
#  5   price                8369 non-null   float64
#  6   Insurance Validity   8369 non-null   int64
#  7   Engine Displacement  8369 non-null   float64
#  8   Color                8369 non-null   int64
#  9   Engine Type          8369 non-null   int64
#  10  No of Cylinder       8369 non-null   float64
#  11  Turbo Charger        8369 non-null   int64
#  12  Length               8369 non-null   float64
#  13  Width                8369 non-null   float64
#  14  Height               8369 non-null   float64
# ...

# %%
## reading raw data

raw_data = pd.read_csv('car_details.csv')

raw_data.head()
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_28620\1285509942.py:3: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_data = pd.read_csv('car_details.csv')
#    ignition_type fuel_type  body_type kilometers_driven transmission  ownerNo  \
# 0              0    Petrol        SUV            20,000    Automatic        1
# 1              0    Petrol   Minivans            20,687       Manual        1
# 2              0    Petrol        SUV            30,000       Manual        1
# 3              0    Petrol  Hatchback            59,247       Manual        1
# 4              0    Petrol  Hatchback            50,000       Manual        1
#
#        owner      oem           model  modelYear  ...  Compression Ratio  \
# 0  1st Owner      Kia       Kia Sonet       2022  ...                NaN
# 1  1st Owner   Maruti     Maruti Eeco       2015  ...              9.9:1
# ...

# %%
## pairplot 

pairplot = data.iloc[:, :10]

sns.pairplot(pairplot)

plt.show()

# %%
## distributions of features

plt.figure(figsize=(15, 12))  # Adjust figure size for better visibility
for idx, feature in enumerate(data.columns, 1):  # Start index from 1
    plt.subplot(6, 5, idx)  # Provide all three arguments (rows, cols, index)
    sns.histplot(data=data[feature], bins=20, kde=True)
    plt.title(feature)

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
## Distribution of Price 

plt.figure(figsize=(15, 3))

sns.histplot(data=data['price'],bins=20, kde=True)
plt.show()

# %%
## body_type distributions

top_data = raw_data['body_type'].value_counts()

plt.figure(figsize=(15, 3))
sns.barplot(x=top_data.values, y=top_data.index)
plt.title('Body Type vs Count')
plt.ylabel('Body Type')
plt.xlabel('Count')
plt.show()

# %%
## correlation of columns

data_corr = data.corr()

plt.figure(figsize=(20, 10))
sns.heatmap(data=data_corr, annot=True, cmap='coolwarm')

plt.show()
